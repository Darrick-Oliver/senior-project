# %%
import pandas as pd
import requests
import json
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split

import shap
import plotly.express as px

from minisom import MiniSom

# For shap to work with keras, disable v2 behavior
tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\Darrick\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
season = '2021-22'
percentile = 0.2

df = pd.read_csv('./stats/' + season + '_' + str(percentile) + '_h2h_stats.csv')
# df = pd.read_csv('./stats/h2h_combined.csv')
df = df.fillna(0)

print(df.shape)
df.head()
# Out:
# (111702, 27)
#    SEASON_ID  OFF_PLAYER_ID OFF_PLAYER_NAME  DEF_PLAYER_ID    DEF_PLAYER_NAME  \
# 0      22021         203932    Aaron Gordon         202711   Bojan Bogdanovic
# 1      22021         203932    Aaron Gordon        1628404          Josh Hart
# 2      22021         203932    Aaron Gordon        1628991  Jaren Jackson Jr.
# 3      22021         203932    Aaron Gordon        1630532       Franz Wagner
# 4      22021         203932    Aaron Gordon        1629640     Keldon Johnson
#
#    GP MATCHUP_MIN  PARTIAL_POSS  PLAYER_PTS  TEAM_PTS  ...  MATCHUP_FG3A  \
# 0   3       17:12          92.0          16        93  ...             4
# 1   2       15:58          72.0          12        62  ...             3
# 2   3       14:31          68.4          11        67  ...             3
# 3   2       14:09          67.8           5        66  ...             2
# 4   2       13:42          62.2           8        60  ...             2
#
#    MATCHUP_FG3_PCT  HELP_BLK  HELP_FGM  HELP_FGA  HELP_FG_PERC  MATCHUP_FTM  \
# 0            0.250         0         0         0             0            1
# 1            0.000         0         0         0             0            0
# 2            0.333         0         0         0             0            4
# 3            0.500         0         0         0             0            0
# 4            0.000         0         0         0             0            0
#
#    MATCHUP_FTA  SFL  MATCHUP_TIME_SEC
# 0            2    0            1031.6
# 1            0    0             957.9
# 2            4    2             870.7
# 3            0    0             849.4
# 4            0    0             821.9
#
# [5 rows x 27 columns]

# %%
def run_model(matchup_mins, bpercent, num_epochs, val_split):
    h2h_df = df.copy()
    h2h_df = h2h_df[h2h_df['MATCHUP_TIME_SEC'] > matchup_mins * 60] # Must have played more than x minutes
    h2h_df.drop(columns=['TEAM_PTS', 'MATCHUP_FG_PCT', 'MATCHUP_FG3_PCT'], inplace=True)

    def per_100_poss(x):
        return x / h2h_df['PARTIAL_POSS'] * 100

    # Set stats to per 100 possessions
    h2h_df = h2h_df.apply(lambda x: per_100_poss(x) if x.name not in h2h_df.columns[0:8] else x)

    h2h_df.sort_values('DEF_PLAYER_NAME', ascending=True, inplace=True)

    # Remove rows with zeros in important columns
    check = h2h_df[h2h_df.columns[8:11]] != 0
    h2h_df = h2h_df[check['PLAYER_PTS'] & check['MATCHUP_AST']]

    out = h2h_df

    data = pd.read_csv('./stats/'+ season + '_def_stats.csv')
    data = data.fillna(0)

    # Get def stats only from selected defenders (rename player_id to def_player_id to merge arrays)
    data = data.add_prefix('DEF_')
    data.rename(columns={'DEF_SEASON_ID': 'SEASON_ID', 'DEF_DEF_RATING': 'DEF_RATING', 
                        'DEF_DEF_BOXOUTS': 'DEF_BOXOUTS'}, inplace=True)
    def_df = pd.merge(data, out[['DEF_PLAYER_ID', 'SEASON_ID']], how ='inner', on=['DEF_PLAYER_ID', 'SEASON_ID'])
    def_df.drop(columns=['DEF_GP', 'DEF_G', 'DEF_D_FG_PCT', 'DEF_DREB_PCT', 'DEF_PCT_STL', 'DEF_PCT_BLK'], inplace=True)

    # Add offensive player (helps merging offensive stats)
    def_df['OFF_PLAYER_ID'] = out['OFF_PLAYER_ID'].to_numpy()
    def_df['OFF_PLAYER_NAME'] = out['OFF_PLAYER_NAME'].to_numpy()

    data = pd.read_csv('./stats/' + season + '_' + str(percentile) + '_off_stats.csv')
    data = data.fillna(0)

    # Get off stats only from selected offensive players
    data = data.add_prefix('OFF_')
    data.rename(columns={'OFF_SEASON_ID': 'SEASON_ID'}, inplace=True)
    combine = pd.merge(def_df, data, how='inner', on=['OFF_PLAYER_ID', 'SEASON_ID'])

    # Get correct sort
    combine.sort_values(['DEF_PLAYER_ID', 'OFF_PLAYER_ID'], inplace=True)

    # Sort head to head stats by same sort
    h2h_df.sort_values(['DEF_PLAYER_ID', 'OFF_PLAYER_ID'], inplace=True)

    # Clean data to use on model
    X = combine.drop(columns=['DEF_PLAYER_ID', 'DEF_PLAYER_NAME', 'OFF_PLAYER_ID', 'OFF_PLAYER_NAME', 'SEASON_ID'])
    y = out['PLAYER_PTS']

    # Save to csvs
    X.to_csv('./stats/cleaned/' + season + '_X.csv', index=False)
    y.to_csv('./stats/cleaned/' + season + '_y.csv', index=False)

    # Apply normalization to input
    X = (X - X.mean()) / X.std()

    # Generate training and verification data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    X_train = X_train.to_numpy()
    X_test = X_test.to_numpy()
    y_train = y_train.to_numpy()
    y_test = y_test.to_numpy()

    # Create model
    model = Sequential()
    model.add(Dense(int(X.shape[1] / 2), activation='relu', input_shape=(X.shape[1],)))
    model.add(Dropout(0.7))
    model.add(Dense(1, activation='relu')) # y.shape[1]

    # Compile model
    model.compile(optimizer='nadam', loss='mean_squared_error', metrics=['accuracy'])

    # Fit model
    bsize = int(X_train.shape[0] * bpercent) # 30% batch size

    history = model.fit(X_train, y_train, epochs=num_epochs, validation_split=val_split, batch_size=bsize, verbose=0)

    y_pred = model.predict(X_test)
    score = model.evaluate(X_test, y_test)
    
    diff = abs(y_pred.flatten() - y_test.flatten())
    predictions = pd.DataFrame(data={'predicted': y_pred.flatten(), 'actual': y_test.flatten(), 'abs_diff': diff})
    predictions.sort_values(by='abs_diff', inplace=True)

    return score[0], predictions.quantile(q=0.5)['abs_diff'], (len(predictions[predictions['abs_diff'] < 5]) / len(predictions) * 100), (history.history['loss'][len(history.history['loss']) - 1] < history.history['val_loss'][len(history.history['val_loss']) - 1])

# %%
def run_premade(drop_percent, bpercent, num_epochs, val_split):
    X = pd.read_csv('./stats/cleaned/X_combined.csv')
    y = pd.read_csv('./stats/cleaned/y_combined.csv')

    # Apply normalization to input
    X = (X - X.mean()) / X.std()

    # Generate training and verification data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    X_train = X_train.to_numpy()
    X_test = X_test.to_numpy()
    y_train = y_train.to_numpy()
    y_test = y_test.to_numpy()

    # Create model
    model = Sequential()
    model.add(Dense(int(X.shape[1] / 2), activation='relu', input_shape=(X.shape[1],)))
    model.add(Dropout(drop_percent))
    model.add(Dense(1, activation='relu')) # y.shape[1]

    # Compile model
    model.compile(optimizer='nadam', loss='mean_squared_error', metrics=['accuracy'])

    # Fit model
    bsize = int(X_train.shape[0] * bpercent) # 30% batch size

    history = model.fit(X_train, y_train, epochs=num_epochs, validation_split=val_split, batch_size=bsize, verbose=0)

    y_pred = model.predict(X_test)
    score = model.evaluate(X_test, y_test)
    
    diff = abs(y_pred.flatten() - y_test.flatten())
    predictions = pd.DataFrame(data={'predicted': y_pred.flatten(), 'actual': y_test.flatten(), 'abs_diff': diff})
    predictions.sort_values(by='abs_diff', inplace=True)

    return score[0], predictions.quantile(q=0.5)['abs_diff'], (len(predictions[predictions['abs_diff'] < 5]) / len(predictions) * 100), (history.history['loss'][len(history.history['loss']) - 1] < history.history['val_loss'][len(history.history['val_loss']) - 1])

# %%
cols = ['Dropout%', 'Batch', 'Epochs', 'Loss', '50th Quantile', '%Accept', 'Overfit']

result_df = pd.DataFrame(columns=cols)

for drop in np.arange(0.3, 0.9, 0.1):
    for batch in np.arange(0.3, 0.8, 0.1):
        for epochs in range(1000, 11000, 3000):
            loss, q, pa, overfit = run_premade(round(drop, 1), round(batch, 1), epochs, 0.2)
            result_df = result_df.append({
                'Dropout%': round(drop, 1),
                'Batch': round(batch, 1),
                'Epochs': epochs,
                'Loss': loss,
                '50th Quantile': q,
                '%Accept': pa,
                'Overfit': overfit
            }, ignore_index=True)
            
            print({
                'Dropout%': round(drop, 1),
                'Batch': round(batch, 1),
                'Epochs': epochs,
                'Loss': loss,
                '50th Quantile': q,
                '%Accept': pa,
                'Overfit': overfit
            })
# Out:
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# {'Dropout%': 0.3, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 65.65676697256825, '50th Quantile': 5.182888551354967, '%Accept': 48.98336414048059, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.3, 'Epochs': 4000, 'Loss': 79.55321227688886, '50th Quantile': 5.471959839597268, '%Accept': 45.65619223659889, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.3, 'Epochs': 7000, 'Loss': 79.48040891354714, '50th Quantile': 5.331375197796309, '%Accept': 47.504621072088725, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.3, 'Epochs': 10000, 'Loss': 87.9646224834562, '50th Quantile': 5.793517401802363, '%Accept': 45.4713493530499, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 62.44987807212167, '50th Quantile': 5.012439528363952, '%Accept': 49.72273567467653, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.4, 'Epochs': 4000, 'Loss': 67.83137340157839, '50th Quantile': 5.224307508817386, '%Accept': 46.58040665434381, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.4, 'Epochs': 7000, 'Loss': 69.65023176859576, '50th Quantile': 5.319920509888373, '%Accept': 47.689463955637706, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.4, 'Epochs': 10000, 'Loss': 82.01221980801792, '50th Quantile': 5.180666248972823, '%Accept': 47.874306839186694, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 70.66688893683076, '50th Quantile': 5.712140646556881, '%Accept': 44.73197781885398, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.5, 'Epochs': 4000, 'Loss': 67.09815641956718, '50th Quantile': 4.9827571807097275, '%Accept': 50.27726432532348, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.5, 'Epochs': 7000, 'Loss': 69.37692314331281, '50th Quantile': 5.433534304300942, '%Accept': 46.58040665434381, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.5, 'Epochs': 10000, 'Loss': 89.09391401082883, '50th Quantile': 5.551068500596646, '%Accept': 44.91682070240296, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 77.1399748091777, '50th Quantile': 5.626684700921288, '%Accept': 44.73197781885398, 'Overfit': False}
# {'Dropout%': 0.3, 'Batch': 0.6, 'Epochs': 4000, 'Loss': 64.58094848237945, '50th Quantile': 4.824223979826895, '%Accept': 51.20147874306839, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.6, 'Epochs': 7000, 'Loss': 73.89142710179807, '50th Quantile': 5.3599571488861315, '%Accept': 46.76524953789279, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.6, 'Epochs': 10000, 'Loss': 81.35057545942212, '50th Quantile': 5.589952008477578, '%Accept': 46.39556377079482, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 66.03311962473194, '50th Quantile': 5.44596525498892, '%Accept': 45.4713493530499, 'Overfit': False}
# {'Dropout%': 0.3, 'Batch': 0.7, 'Epochs': 4000, 'Loss': 73.5222736013134, '50th Quantile': 5.488188634478497, '%Accept': 46.21072088724584, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.7, 'Epochs': 7000, 'Loss': 74.61344271534692, '50th Quantile': 5.231129614131628, '%Accept': 48.24399260628466, 'Overfit': True}
# {'Dropout%': 0.3, 'Batch': 0.7, 'Epochs': 10000, 'Loss': 76.70665168409647, '50th Quantile': 5.5523251061885635, '%Accept': 46.02587800369686, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 68.67074969956262, '50th Quantile': 4.850119772921788, '%Accept': 52.31053604436229, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.3, 'Epochs': 4000, 'Loss': 73.62193556413632, '50th Quantile': 5.196350037958327, '%Accept': 48.24399260628466, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.3, 'Epochs': 7000, 'Loss': 71.39338260305126, '50th Quantile': 5.378405559593638, '%Accept': 47.31977818853974, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.3, 'Epochs': 10000, 'Loss': 72.30889850270947, '50th Quantile': 5.561584968877028, '%Accept': 46.21072088724584, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 71.62442357879469, '50th Quantile': 4.983253217723272, '%Accept': 50.64695009242144, 'Overfit': False}
# {'Dropout%': 0.4, 'Batch': 0.4, 'Epochs': 4000, 'Loss': 67.8896918164604, '50th Quantile': 5.030356784199565, '%Accept': 49.72273567467653, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.4, 'Epochs': 7000, 'Loss': 70.93884373240022, '50th Quantile': 5.566582758664083, '%Accept': 45.4713493530499, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.4, 'Epochs': 10000, 'Loss': 87.28627259541791, '50th Quantile': 6.123512796550912, '%Accept': 43.622920517560075, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 69.18133815687818, '50th Quantile': 5.578135392973373, '%Accept': 44.91682070240296, 'Overfit': False}
# {'Dropout%': 0.4, 'Batch': 0.5, 'Epochs': 4000, 'Loss': 65.90478208897956, '50th Quantile': 5.24394187807663, '%Accept': 47.504621072088725, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.5, 'Epochs': 7000, 'Loss': 69.26456249046679, '50th Quantile': 5.064041006154035, '%Accept': 49.35304990757856, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.5, 'Epochs': 10000, 'Loss': 82.19477972570056, '50th Quantile': 5.782743212609372, '%Accept': 43.992606284658045, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 65.5014212673561, '50th Quantile': 5.423212099476018, '%Accept': 46.950092421441774, 'Overfit': False}
# {'Dropout%': 0.4, 'Batch': 0.6, 'Epochs': 4000, 'Loss': 74.0802252411622, '50th Quantile': 5.09926511289121, '%Accept': 48.98336414048059, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.6, 'Epochs': 7000, 'Loss': 75.76004638953923, '50th Quantile': 5.420913299458139, '%Accept': 47.13493530499076, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.6, 'Epochs': 10000, 'Loss': 76.70042295332537, '50th Quantile': 5.474059415667249, '%Accept': 46.02587800369686, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 82.42394143772654, '50th Quantile': 5.716668982393678, '%Accept': 44.91682070240296, 'Overfit': False}
# {'Dropout%': 0.4, 'Batch': 0.7, 'Epochs': 4000, 'Loss': 68.25538436410167, '50th Quantile': 5.08539373546728, '%Accept': 49.35304990757856, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.7, 'Epochs': 7000, 'Loss': 82.42140626466649, '50th Quantile': 5.551510435318594, '%Accept': 46.58040665434381, 'Overfit': True}
# {'Dropout%': 0.4, 'Batch': 0.7, 'Epochs': 10000, 'Loss': 66.32086246511632, '50th Quantile': 5.56954985398513, '%Accept': 45.28650646950093, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 72.30555557984302, '50th Quantile': 5.30226905104043, '%Accept': 48.98336414048059, 'Overfit': False}
# {'Dropout%': 0.5, 'Batch': 0.3, 'Epochs': 4000, 'Loss': 70.17719356233664, '50th Quantile': 5.412509632861521, '%Accept': 46.950092421441774, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.3, 'Epochs': 7000, 'Loss': 66.51311501381358, '50th Quantile': 5.165058633555537, '%Accept': 49.16820702402958, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.3, 'Epochs': 10000, 'Loss': 80.97988712501173, '50th Quantile': 5.395541967347613, '%Accept': 45.65619223659889, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 74.65822079529823, '50th Quantile': 4.829622268676758, '%Accept': 51.386321626617374, 'Overfit': False}
# {'Dropout%': 0.5, 'Batch': 0.4, 'Epochs': 4000, 'Loss': 63.41632895548992, '50th Quantile': 5.357606811903011, '%Accept': 48.24399260628466, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.4, 'Epochs': 7000, 'Loss': 69.96765941965381, '50th Quantile': 5.134435148587894, '%Accept': 48.98336414048059, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.4, 'Epochs': 10000, 'Loss': 67.41851503439179, '50th Quantile': 5.086839334522367, '%Accept': 49.35304990757856, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 64.63283427409456, '50th Quantile': 4.949322106703271, '%Accept': 50.09242144177449, 'Overfit': False}
# {'Dropout%': 0.5, 'Batch': 0.5, 'Epochs': 4000, 'Loss': 63.49352954716427, '50th Quantile': 5.202314150083314, '%Accept': 48.98336414048059, 'Overfit': False}
# {'Dropout%': 0.5, 'Batch': 0.5, 'Epochs': 7000, 'Loss': 69.12741473862512, '50th Quantile': 5.179651480953709, '%Accept': 48.79852125693161, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.5, 'Epochs': 10000, 'Loss': 74.4951341526786, '50th Quantile': 5.826135990231535, '%Accept': 45.28650646950093, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 64.70385266231742, '50th Quantile': 4.9199891771589, '%Accept': 50.46210720887245, 'Overfit': False}
# {'Dropout%': 0.5, 'Batch': 0.6, 'Epochs': 4000, 'Loss': 61.14585221408696, '50th Quantile': 4.5175018356562475, '%Accept': 53.789279112754166, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.6, 'Epochs': 7000, 'Loss': 63.06484837981557, '50th Quantile': 5.277772730047051, '%Accept': 49.16820702402958, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.6, 'Epochs': 10000, 'Loss': 68.36284489376047, '50th Quantile': 4.991968860670887, '%Accept': 50.09242144177449, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 70.45067874252686, '50th Quantile': 4.968693296153596, '%Accept': 50.27726432532348, 'Overfit': False}
# {'Dropout%': 0.5, 'Batch': 0.7, 'Epochs': 4000, 'Loss': 67.40317741295327, '50th Quantile': 5.12117344400157, '%Accept': 49.35304990757856, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.7, 'Epochs': 7000, 'Loss': 70.63303724983483, '50th Quantile': 5.137604835705879, '%Accept': 49.16820702402958, 'Overfit': True}
# {'Dropout%': 0.5, 'Batch': 0.7, 'Epochs': 10000, 'Loss': 73.20793904923246, '50th Quantile': 5.381716701760315, '%Accept': 47.874306839186694, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 70.19151452817229, '50th Quantile': 4.861117519643631, '%Accept': 51.940850277264325, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.3, 'Epochs': 4000, 'Loss': 64.6382222413576, '50th Quantile': 5.023000795688816, '%Accept': 49.53789279112754, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.3, 'Epochs': 7000, 'Loss': 70.06626954845493, '50th Quantile': 4.9559290770775775, '%Accept': 50.27726432532348, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.3, 'Epochs': 10000, 'Loss': 68.12152610821116, '50th Quantile': 5.4159866217105535, '%Accept': 46.21072088724584, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 70.65636118326522, '50th Quantile': 5.195911786642419, '%Accept': 47.874306839186694, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.4, 'Epochs': 4000, 'Loss': 64.96761692914416, '50th Quantile': 5.051003478860936, '%Accept': 49.53789279112754, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.4, 'Epochs': 7000, 'Loss': 74.45925601529106, '50th Quantile': 5.177688667739648, '%Accept': 48.24399260628466, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.4, 'Epochs': 10000, 'Loss': 66.55569180190673, '50th Quantile': 5.233322676265221, '%Accept': 47.13493530499076, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 77.14866693888045, '50th Quantile': 5.547797681983382, '%Accept': 43.992606284658045, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.5, 'Epochs': 4000, 'Loss': 67.56185164953997, '50th Quantile': 4.791602708061657, '%Accept': 51.75600739371534, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.5, 'Epochs': 7000, 'Loss': 69.47898603851826, '50th Quantile': 5.507196289261962, '%Accept': 45.10166358595194, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.5, 'Epochs': 10000, 'Loss': 75.1682107188565, '50th Quantile': 5.5872512346847465, '%Accept': 46.02587800369686, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 81.03873392834902, '50th Quantile': 5.307582333997207, '%Accept': 47.689463955637706, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.6, 'Epochs': 4000, 'Loss': 65.3117898458033, '50th Quantile': 5.274122576341561, '%Accept': 48.24399260628466, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.6, 'Epochs': 7000, 'Loss': 68.00370689857469, '50th Quantile': 5.153508765964107, '%Accept': 48.24399260628466, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.6, 'Epochs': 10000, 'Loss': 73.22566709677085, '50th Quantile': 5.253300233483873, '%Accept': 47.31977818853974, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 67.55926900077439, '50th Quantile': 5.08783034961748, '%Accept': 48.79852125693161, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.7, 'Epochs': 4000, 'Loss': 67.43438524679864, '50th Quantile': 5.322961262294225, '%Accept': 47.874306839186694, 'Overfit': False}
# {'Dropout%': 0.6, 'Batch': 0.7, 'Epochs': 7000, 'Loss': 72.30562922958967, '50th Quantile': 5.831645965576172, '%Accept': 44.73197781885398, 'Overfit': True}
# {'Dropout%': 0.6, 'Batch': 0.7, 'Epochs': 10000, 'Loss': 67.56078177855768, '50th Quantile': 5.351823046060602, '%Accept': 46.950092421441774, 'Overfit': True}
# {'Dropout%': 0.7, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 67.56363635671337, '50th Quantile': 4.799854224251337, '%Accept': 52.68022181146026, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.3, 'Epochs': 4000, 'Loss': 61.721465161899985, '50th Quantile': 5.066024532163048, '%Accept': 49.35304990757856, 'Overfit': True}
# {'Dropout%': 0.7, 'Batch': 0.3, 'Epochs': 7000, 'Loss': 63.36384755978963, '50th Quantile': 5.484937175627676, '%Accept': 45.4713493530499, 'Overfit': True}
# {'Dropout%': 0.7, 'Batch': 0.3, 'Epochs': 10000, 'Loss': 66.9500671288002, '50th Quantile': 5.2985483785026, '%Accept': 48.24399260628466, 'Overfit': True}
# {'Dropout%': 0.7, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 81.8943780275017, '50th Quantile': 5.108448606548887, '%Accept': 48.98336414048059, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.4, 'Epochs': 4000, 'Loss': 57.833443495350274, '50th Quantile': 4.873282460905568, '%Accept': 50.83179297597042, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.4, 'Epochs': 7000, 'Loss': 66.58855635665921, '50th Quantile': 4.720859946491563, '%Accept': 51.940850277264325, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.4, 'Epochs': 10000, 'Loss': 80.26054619244418, '50th Quantile': 5.978879517815569, '%Accept': 41.21996303142329, 'Overfit': True}
# {'Dropout%': 0.7, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 86.14239817846725, '50th Quantile': 5.344034878475708, '%Accept': 47.504621072088725, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.5, 'Epochs': 4000, 'Loss': 65.4626565534835, '50th Quantile': 5.069419619865476, '%Accept': 49.53789279112754, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.5, 'Epochs': 7000, 'Loss': 65.58571451296427, '50th Quantile': 4.861861311737748, '%Accept': 50.64695009242144, 'Overfit': True}
# {'Dropout%': 0.7, 'Batch': 0.5, 'Epochs': 10000, 'Loss': 61.22877158343021, '50th Quantile': 5.508461098658444, '%Accept': 45.65619223659889, 'Overfit': True}
# {'Dropout%': 0.7, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 76.60495275754805, '50th Quantile': 5.101984173643821, '%Accept': 49.53789279112754, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.6, 'Epochs': 4000, 'Loss': 72.56061314214399, '50th Quantile': 5.261071582173198, '%Accept': 48.24399260628466, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.6, 'Epochs': 7000, 'Loss': 56.70707870455194, '50th Quantile': 4.72412471634021, '%Accept': 52.495378927911275, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.6, 'Epochs': 10000, 'Loss': 63.06333498857819, '50th Quantile': 5.13507743934532, '%Accept': 49.16820702402958, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 80.34055522982162, '50th Quantile': 5.167201567543536, '%Accept': 48.79852125693161, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.7, 'Epochs': 4000, 'Loss': 69.28299012245841, '50th Quantile': 5.265836270269521, '%Accept': 47.689463955637706, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.7, 'Epochs': 7000, 'Loss': 64.47212840448687, '50th Quantile': 5.249501113131512, '%Accept': 47.874306839186694, 'Overfit': False}
# {'Dropout%': 0.7, 'Batch': 0.7, 'Epochs': 10000, 'Loss': 61.902914389224236, '50th Quantile': 5.301219496779778, '%Accept': 46.58040665434381, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 74.05918031082577, '50th Quantile': 5.188020789067023, '%Accept': 48.98336414048059, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.3, 'Epochs': 4000, 'Loss': 62.070626080807386, '50th Quantile': 4.988125101577918, '%Accept': 50.27726432532348, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.3, 'Epochs': 7000, 'Loss': 68.67821885565513, '50th Quantile': 4.970053234180821, '%Accept': 50.27726432532348, 'Overfit': True}
# {'Dropout%': 0.8, 'Batch': 0.3, 'Epochs': 10000, 'Loss': 73.99098971326337, '50th Quantile': 5.456270853678383, '%Accept': 45.10166358595194, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 72.32143624917417, '50th Quantile': 4.86623304501466, '%Accept': 50.83179297597042, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.4, 'Epochs': 4000, 'Loss': 70.24978574234545, '50th Quantile': 4.795198686661259, '%Accept': 51.386321626617374, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.4, 'Epochs': 7000, 'Loss': 69.43100822434629, '50th Quantile': 5.158656558072771, '%Accept': 48.79852125693161, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.4, 'Epochs': 10000, 'Loss': 70.83734181627989, '50th Quantile': 5.279766008174619, '%Accept': 48.428835489833645, 'Overfit': True}
# {'Dropout%': 0.8, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 73.35116170999524, '50th Quantile': 5.186619676736004, '%Accept': 48.79852125693161, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.5, 'Epochs': 4000, 'Loss': 64.98785721925182, '50th Quantile': 4.618497899470438, '%Accept': 52.68022181146026, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.5, 'Epochs': 7000, 'Loss': 63.5147642040429, '50th Quantile': 4.977105586624813, '%Accept': 50.27726432532348, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.5, 'Epochs': 10000, 'Loss': 63.71498581750556, '50th Quantile': 5.370802796731784, '%Accept': 47.31977818853974, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 83.42191388029708, '50th Quantile': 5.226856806921581, '%Accept': 47.31977818853974, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.6, 'Epochs': 4000, 'Loss': 75.67663895753307, '50th Quantile': 5.538363857507375, '%Accept': 46.39556377079482, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.6, 'Epochs': 7000, 'Loss': 67.94642311984641, '50th Quantile': 4.827127365678445, '%Accept': 50.64695009242144, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.6, 'Epochs': 10000, 'Loss': 68.45307578264895, '50th Quantile': 5.408685141085934, '%Accept': 47.13493530499076, 'Overfit': True}
# {'Dropout%': 0.8, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 87.00018860540196, '50th Quantile': 5.326515271349351, '%Accept': 46.950092421441774, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.7, 'Epochs': 4000, 'Loss': 59.04451432289786, '50th Quantile': 4.921925030096116, '%Accept': 51.01663585951941, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.7, 'Epochs': 7000, 'Loss': 62.624844986497806, '50th Quantile': 4.763478253338793, '%Accept': 51.20147874306839, 'Overfit': False}
# {'Dropout%': 0.8, 'Batch': 0.7, 'Epochs': 10000, 'Loss': 65.6780100626778, '50th Quantile': 5.454067350372554, '%Accept': 46.58040665434381, 'Overfit': True}
# {'Dropout%': 0.9, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 84.86925113135037, '50th Quantile': 5.6626456811362225, '%Accept': 45.28650646950093, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.3, 'Epochs': 4000, 'Loss': 68.09665655957573, '50th Quantile': 4.897284251329509, '%Accept': 50.83179297597042, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.3, 'Epochs': 7000, 'Loss': 64.4878191992007, '50th Quantile': 5.225487514208719, '%Accept': 48.428835489833645, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.3, 'Epochs': 10000, 'Loss': 69.62894284570945, '50th Quantile': 5.4991686933937824, '%Accept': 45.84103512014787, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 86.41558548791572, '50th Quantile': 5.303800900777183, '%Accept': 46.21072088724584, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.4, 'Epochs': 4000, 'Loss': 74.04701002336033, '50th Quantile': 5.272283349300455, '%Accept': 47.874306839186694, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.4, 'Epochs': 7000, 'Loss': 64.41917408856798, '50th Quantile': 4.948175339311257, '%Accept': 50.27726432532348, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.4, 'Epochs': 10000, 'Loss': 72.65600196711458, '50th Quantile': 5.460298018022016, '%Accept': 47.13493530499076, 'Overfit': True}
# {'Dropout%': 0.9, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 92.41464803135109, '50th Quantile': 5.579985454372508, '%Accept': 46.39556377079482, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.5, 'Epochs': 4000, 'Loss': 76.66705755209085, '50th Quantile': 5.244933240973184, '%Accept': 48.24399260628466, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.5, 'Epochs': 7000, 'Loss': 71.74467069164001, '50th Quantile': 5.30570209474492, '%Accept': 46.58040665434381, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.5, 'Epochs': 10000, 'Loss': 70.93002585871163, '50th Quantile': 5.358784210162153, '%Accept': 45.65619223659889, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 101.45801139450778, '50th Quantile': 5.529330229653567, '%Accept': 46.02587800369686, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.6, 'Epochs': 4000, 'Loss': 81.46301897087731, '50th Quantile': 4.7748881253329145, '%Accept': 51.571164510166355, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.6, 'Epochs': 7000, 'Loss': 68.94258944076002, '50th Quantile': 5.09186593535121, '%Accept': 49.16820702402958, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.6, 'Epochs': 10000, 'Loss': 72.48334092794197, '50th Quantile': 5.716845270723351, '%Accept': 42.883548983364136, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 87.02673321510639, '50th Quantile': 5.5960653948165495, '%Accept': 43.438077634011094, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.7, 'Epochs': 4000, 'Loss': 69.21866616127451, '50th Quantile': 4.611918853501145, '%Accept': 53.41959334565619, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.7, 'Epochs': 7000, 'Loss': 72.41254181077431, '50th Quantile': 5.176598799856091, '%Accept': 47.874306839186694, 'Overfit': False}
# {'Dropout%': 0.9, 'Batch': 0.7, 'Epochs': 10000, 'Loss': 66.6915918374899, '50th Quantile': 5.341688458628964, '%Accept': 47.13493530499076, 'Overfit': False}

# %%
result_df.to_csv('./results.csv')

# %%
result_df
# Out:
#      Dropout%  Batch Epochs       Loss  50th Quantile    %Accept Overfit
# 0         0.3    0.3   1000  65.656767       5.182889  48.983364    True
# 1         0.3    0.3   4000  79.553212       5.471960  45.656192    True
# 2         0.3    0.3   7000  79.480409       5.331375  47.504621    True
# 3         0.3    0.3  10000  87.964622       5.793517  45.471349    True
# 4         0.3    0.4   1000  62.449878       5.012440  49.722736    True
# ..        ...    ...    ...        ...            ...        ...     ...
# 135       0.9    0.6  10000  72.483341       5.716845  42.883549   False
# 136       0.9    0.7   1000  87.026733       5.596065  43.438078   False
# 137       0.9    0.7   4000  69.218666       4.611919  53.419593   False
# 138       0.9    0.7   7000  72.412542       5.176599  47.874307   False
# 139       0.9    0.7  10000  66.691592       5.341688  47.134935   False
#
# [140 rows x 7 columns]
