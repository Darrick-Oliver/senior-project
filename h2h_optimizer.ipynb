# %%
import pandas as pd
import requests
import json
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split

import shap
import plotly.express as px

from minisom import MiniSom

# For shap to work with keras, disable v2 behavior
tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\Darrick\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
season = '2021-22'
percentile = 0.2

df = pd.read_csv('./stats/' + season + '_' + str(percentile) + '_h2h_stats.csv')
# df = pd.read_csv('./stats/h2h_combined.csv')
df = df.fillna(0)

print(df.shape)
df.head()
# Out:
# (111702, 27)
#    SEASON_ID  OFF_PLAYER_ID OFF_PLAYER_NAME  DEF_PLAYER_ID    DEF_PLAYER_NAME  \
# 0      22021         203932    Aaron Gordon         202711   Bojan Bogdanovic
# 1      22021         203932    Aaron Gordon        1628404          Josh Hart
# 2      22021         203932    Aaron Gordon        1628991  Jaren Jackson Jr.
# 3      22021         203932    Aaron Gordon        1630532       Franz Wagner
# 4      22021         203932    Aaron Gordon        1629640     Keldon Johnson
#
#    GP MATCHUP_MIN  PARTIAL_POSS  PLAYER_PTS  TEAM_PTS  ...  MATCHUP_FG3A  \
# 0   3       17:12          92.0          16        93  ...             4
# 1   2       15:58          72.0          12        62  ...             3
# 2   3       14:31          68.4          11        67  ...             3
# 3   2       14:09          67.8           5        66  ...             2
# 4   2       13:42          62.2           8        60  ...             2
#
#    MATCHUP_FG3_PCT  HELP_BLK  HELP_FGM  HELP_FGA  HELP_FG_PERC  MATCHUP_FTM  \
# 0            0.250         0         0         0             0            1
# 1            0.000         0         0         0             0            0
# 2            0.333         0         0         0             0            4
# 3            0.500         0         0         0             0            0
# 4            0.000         0         0         0             0            0
#
#    MATCHUP_FTA  SFL  MATCHUP_TIME_SEC
# 0            2    0            1031.6
# 1            0    0             957.9
# 2            4    2             870.7
# 3            0    0             849.4
# 4            0    0             821.9
#
# [5 rows x 27 columns]

# %%
def run_model(matchup_mins, bpercent, num_epochs, val_split):
    h2h_df = df.copy()
    h2h_df = h2h_df[h2h_df['MATCHUP_TIME_SEC'] > matchup_mins * 60] # Must have played more than x minutes
    h2h_df.drop(columns=['TEAM_PTS', 'MATCHUP_FG_PCT', 'MATCHUP_FG3_PCT'], inplace=True)

    def per_100_poss(x):
        return x / h2h_df['PARTIAL_POSS'] * 100

    # Set stats to per 100 possessions
    h2h_df = h2h_df.apply(lambda x: per_100_poss(x) if x.name not in h2h_df.columns[0:8] else x)

    h2h_df.sort_values('DEF_PLAYER_NAME', ascending=True, inplace=True)

    # Remove rows with zeros in important columns
    check = h2h_df[h2h_df.columns[8:11]] != 0
    h2h_df = h2h_df[check['PLAYER_PTS'] & check['MATCHUP_AST']]

    out = h2h_df

    data = pd.read_csv('./stats/'+ season + '_def_stats.csv')
    data = data.fillna(0)

    # Get def stats only from selected defenders (rename player_id to def_player_id to merge arrays)
    data = data.add_prefix('DEF_')
    data.rename(columns={'DEF_SEASON_ID': 'SEASON_ID', 'DEF_DEF_RATING': 'DEF_RATING', 
                        'DEF_DEF_BOXOUTS': 'DEF_BOXOUTS'}, inplace=True)
    def_df = pd.merge(data, out[['DEF_PLAYER_ID', 'SEASON_ID']], how ='inner', on=['DEF_PLAYER_ID', 'SEASON_ID'])
    def_df.drop(columns=['DEF_GP', 'DEF_G', 'DEF_D_FG_PCT', 'DEF_DREB_PCT', 'DEF_PCT_STL', 'DEF_PCT_BLK'], inplace=True)

    # Add offensive player (helps merging offensive stats)
    def_df['OFF_PLAYER_ID'] = out['OFF_PLAYER_ID'].to_numpy()
    def_df['OFF_PLAYER_NAME'] = out['OFF_PLAYER_NAME'].to_numpy()

    data = pd.read_csv('./stats/' + season + '_' + str(percentile) + '_off_stats.csv')
    data = data.fillna(0)

    # Get off stats only from selected offensive players
    data = data.add_prefix('OFF_')
    data.rename(columns={'OFF_SEASON_ID': 'SEASON_ID'}, inplace=True)
    combine = pd.merge(def_df, data, how='inner', on=['OFF_PLAYER_ID', 'SEASON_ID'])

    # Get correct sort
    combine.sort_values(['DEF_PLAYER_ID', 'OFF_PLAYER_ID'], inplace=True)

    # Sort head to head stats by same sort
    h2h_df.sort_values(['DEF_PLAYER_ID', 'OFF_PLAYER_ID'], inplace=True)

    # Clean data to use on model
    X = combine.drop(columns=['DEF_PLAYER_ID', 'DEF_PLAYER_NAME', 'OFF_PLAYER_ID', 'OFF_PLAYER_NAME', 'SEASON_ID'])
    y = out['PLAYER_PTS']

    # Save to csvs
    X.to_csv('./stats/cleaned/' + season + '_X.csv', index=False)
    y.to_csv('./stats/cleaned/' + season + '_y.csv', index=False)

    # Apply normalization to input
    X = (X - X.mean()) / X.std()

    # Generate training and verification data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    X_train = X_train.to_numpy()
    X_test = X_test.to_numpy()
    y_train = y_train.to_numpy()
    y_test = y_test.to_numpy()

    # Create model
    model = Sequential()
    model.add(Dense(int(X.shape[1] / 2), activation='relu', input_shape=(X.shape[1],)))
    model.add(Dropout(0.7))
    model.add(Dense(1, activation='relu')) # y.shape[1]

    # Compile model
    model.compile(optimizer='nadam', loss='mean_squared_error', metrics=['accuracy'])

    # Fit model
    bsize = int(X_train.shape[0] * bpercent) # 30% batch size

    history = model.fit(X_train, y_train, epochs=num_epochs, validation_split=val_split, batch_size=bsize, verbose=0)

    y_pred = model.predict(X_test)
    score = model.evaluate(X_test, y_test)

    # !!!!!!!!!!!!!! LOSS !!!!!!!!!!!
    

    diff = abs(y_pred.flatten() - y_test.flatten())
    predictions = pd.DataFrame(data={'predicted': y_pred.flatten(), 'actual': y_test.flatten(), 'abs_diff': diff})
    predictions.sort_values(by='abs_diff', inplace=True)

    return score[0], predictions.quantile(q=0.5)['abs_diff'], (len(predictions[predictions['abs_diff'] < 5]) / len(predictions) * 100), (history.history['loss'][len(history.history['loss']) - 1] < history.history['val_loss'][len(history.history['val_loss']) - 1])

# %%
cols = ['Matchup time', 'Batch', 'Epochs', 'Loss', '50th Quantile', '%Accept', 'Overfit']

result_df = pd.DataFrame(columns=cols)

for min in range(7, 15):
    for batch in np.arange(0.3, 0.8, 0.1):
        for epochs in range(1000, 4000, 1000):
            loss, q, pa, overfit = run_model(min, round(batch, 1), epochs, 0.2)
            result_df = result_df.append({
                'Matchup time': min,
                'Batch': round(batch, 1),
                'Epochs': epochs,
                'Loss': loss,
                '50th Quantile': q,
                '%Accept': pa,
                'Overfit': overfit
            }, ignore_index=True)
            
            print({
                'Matchup time': min,
                'Batch': round(batch, 1),
                'Epochs': epochs,
                'Loss': loss,
                '50th Quantile': q,
                '%Accept': pa,
                'Overfit': overfit
            })
# Out:
# {'Matchup time': 7, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 93.49863914753901, '50th Quantile': 6.103210773433526, '%Accept': 41.34419551934827, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.3, 'Epochs': 2000, 'Loss': 99.74887384853635, '50th Quantile': 5.651342011650524, '%Accept': 44.602851323828915, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.3, 'Epochs': 3000, 'Loss': 98.86570624761329, '50th Quantile': 6.485210421317561, '%Accept': 41.54786150712831, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 97.93888886057432, '50th Quantile': 5.593156213519954, '%Accept': 46.63951120162933, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.4, 'Epochs': 2000, 'Loss': 87.25802239381126, '50th Quantile': 5.787607125376667, '%Accept': 42.973523421588595, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.4, 'Epochs': 3000, 'Loss': 78.58613619056592, '50th Quantile': 5.945731629450766, '%Accept': 41.75152749490835, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 101.24307752092598, '50th Quantile': 5.769789958563377, '%Accept': 44.602851323828915, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.5, 'Epochs': 2000, 'Loss': 92.25156346649356, '50th Quantile': 5.844736241746222, '%Accept': 43.9918533604888, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.5, 'Epochs': 3000, 'Loss': 111.54994332571864, '50th Quantile': 6.0626566750662665, '%Accept': 42.76985743380855, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 102.95145273305734, '50th Quantile': 6.298927013690655, '%Accept': 43.58452138492871, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.6, 'Epochs': 2000, 'Loss': 112.51923314811256, '50th Quantile': 5.988996497551259, '%Accept': 41.54786150712831, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.6, 'Epochs': 3000, 'Loss': 106.92645155679428, '50th Quantile': 6.408310052934382, '%Accept': 43.17718940936864, 'Overfit': True}
# {'Matchup time': 7, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 114.67932391506591, '50th Quantile': 6.696865793794638, '%Accept': 38.69653767820774, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.7, 'Epochs': 2000, 'Loss': 96.96983326525407, '50th Quantile': 5.913981412158977, '%Accept': 41.54786150712831, 'Overfit': False}
# {'Matchup time': 7, 'Batch': 0.7, 'Epochs': 3000, 'Loss': 92.42331000986508, '50th Quantile': 5.780163851651279, '%Accept': 43.78818737270876, 'Overfit': True}
# {'Matchup time': 8, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 99.85630580357143, '50th Quantile': 6.132475250142074, '%Accept': 42.032967032967036, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.3, 'Epochs': 2000, 'Loss': 88.8143642760895, '50th Quantile': 5.699098502319125, '%Accept': 45.604395604395606, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.3, 'Epochs': 3000, 'Loss': 92.90828914432736, '50th Quantile': 6.304136592027254, '%Accept': 38.46153846153847, 'Overfit': True}
# {'Matchup time': 8, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 89.22842667129014, '50th Quantile': 5.287649295260143, '%Accept': 48.07692307692308, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.4, 'Epochs': 2000, 'Loss': 86.29568913218739, '50th Quantile': 5.37344913368752, '%Accept': 46.15384615384615, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.4, 'Epochs': 3000, 'Loss': 106.32719438154619, '50th Quantile': 5.66931811847883, '%Accept': 44.78021978021978, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 120.64303815233838, '50th Quantile': 6.924946747157767, '%Accept': 35.714285714285715, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.5, 'Epochs': 2000, 'Loss': 89.71491082160027, '50th Quantile': 5.685417617457269, '%Accept': 42.857142857142854, 'Overfit': True}
# {'Matchup time': 8, 'Batch': 0.5, 'Epochs': 3000, 'Loss': 90.37644715361543, '50th Quantile': 5.818781219482137, '%Accept': 42.857142857142854, 'Overfit': True}
# {'Matchup time': 8, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 95.2670630989494, '50th Quantile': 5.720768860620449, '%Accept': 43.40659340659341, 'Overfit': True}
# {'Matchup time': 8, 'Batch': 0.6, 'Epochs': 2000, 'Loss': 84.56750119387449, '50th Quantile': 5.830132900453819, '%Accept': 43.956043956043956, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.6, 'Epochs': 3000, 'Loss': 79.54713142311181, '50th Quantile': 5.600380217975769, '%Accept': 43.68131868131868, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 88.91457232800158, '50th Quantile': 5.984008207936899, '%Accept': 44.230769230769226, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.7, 'Epochs': 2000, 'Loss': 106.38989903376653, '50th Quantile': 6.334221232295819, '%Accept': 40.934065934065934, 'Overfit': False}
# {'Matchup time': 8, 'Batch': 0.7, 'Epochs': 3000, 'Loss': 100.62494768415179, '50th Quantile': 5.67913259975617, '%Accept': 43.40659340659341, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 86.25991038929332, '50th Quantile': 5.7447297255826415, '%Accept': 45.45454545454545, 'Overfit': True}
# {'Matchup time': 9, 'Batch': 0.3, 'Epochs': 2000, 'Loss': 95.45986174149947, '50th Quantile': 5.620647370721999, '%Accept': 42.54545454545455, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.3, 'Epochs': 3000, 'Loss': 78.48657864657315, '50th Quantile': 6.0108717869591075, '%Accept': 43.63636363636363, 'Overfit': True}
# {'Matchup time': 9, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 104.18056526877663, '50th Quantile': 6.334811081757415, '%Accept': 42.18181818181818, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.4, 'Epochs': 2000, 'Loss': 94.76261548128996, '50th Quantile': 5.3636760443029265, '%Accept': 47.27272727272727, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.4, 'Epochs': 3000, 'Loss': 111.37448322642933, '50th Quantile': 5.584497723762471, '%Accept': 45.45454545454545, 'Overfit': True}
# {'Matchup time': 9, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 104.16319502397018, '50th Quantile': 5.877512886410668, '%Accept': 45.45454545454545, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.5, 'Epochs': 2000, 'Loss': 115.87328165227717, '50th Quantile': 5.884820663322838, '%Accept': 42.54545454545455, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.5, 'Epochs': 3000, 'Loss': 83.75231953014027, '50th Quantile': 5.717264240208198, '%Accept': 45.81818181818182, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 72.53101063121449, '50th Quantile': 5.303811287393376, '%Accept': 48.0, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.6, 'Epochs': 2000, 'Loss': 81.29518965287642, '50th Quantile': 5.87998848585082, '%Accept': 44.36363636363637, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.6, 'Epochs': 3000, 'Loss': 71.29106736616654, '50th Quantile': 6.111038798377626, '%Accept': 40.72727272727273, 'Overfit': True}
# {'Matchup time': 9, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 112.46966100519354, '50th Quantile': 6.185887449369654, '%Accept': 41.81818181818181, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.7, 'Epochs': 2000, 'Loss': 77.79253248734908, '50th Quantile': 5.711989703931307, '%Accept': 45.81818181818182, 'Overfit': False}
# {'Matchup time': 9, 'Batch': 0.7, 'Epochs': 3000, 'Loss': 68.21382978959517, '50th Quantile': 4.804425357760316, '%Accept': 52.36363636363637, 'Overfit': True}
# {'Matchup time': 10, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 85.19581187855114, '50th Quantile': 5.827647742985178, '%Accept': 44.49760765550239, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.3, 'Epochs': 2000, 'Loss': 101.6692291697817, '50th Quantile': 5.784859911017463, '%Accept': 43.54066985645933, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.3, 'Epochs': 3000, 'Loss': 82.36695431065901, '50th Quantile': 5.181623508923948, '%Accept': 47.84688995215311, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 123.62008995530708, '50th Quantile': 5.834661604866149, '%Accept': 44.01913875598086, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.4, 'Epochs': 2000, 'Loss': 80.11032089890476, '50th Quantile': 6.025854981790378, '%Accept': 44.01913875598086, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.4, 'Epochs': 3000, 'Loss': 82.22815291847338, '50th Quantile': 4.97451459683054, '%Accept': 50.717703349282296, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 78.6676083249909, '50th Quantile': 5.265371322631836, '%Accept': 45.45454545454545, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.5, 'Epochs': 2000, 'Loss': 101.65233615710974, '50th Quantile': 5.546482352408122, '%Accept': 44.97607655502392, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.5, 'Epochs': 3000, 'Loss': 76.64043795206901, '50th Quantile': 5.487404973146322, '%Accept': 44.01913875598086, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 104.7506002763812, '50th Quantile': 6.852481538496221, '%Accept': 37.79904306220095, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.6, 'Epochs': 2000, 'Loss': 82.27856043765419, '50th Quantile': 5.81411538772765, '%Accept': 44.01913875598086, 'Overfit': True}
# {'Matchup time': 10, 'Batch': 0.6, 'Epochs': 3000, 'Loss': 92.8884822717694, '50th Quantile': 5.693820918508983, '%Accept': 44.49760765550239, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 114.28470872577869, '50th Quantile': 5.99912243084696, '%Accept': 43.0622009569378, 'Overfit': False}
# {'Matchup time': 10, 'Batch': 0.7, 'Epochs': 2000, 'Loss': 120.48661924663342, '50th Quantile': 6.026747610185531, '%Accept': 39.23444976076555, 'Overfit': True}
# {'Matchup time': 10, 'Batch': 0.7, 'Epochs': 3000, 'Loss': 69.99955366216778, '50th Quantile': 5.856512370862459, '%Accept': 44.49760765550239, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 87.15637288603392, '50th Quantile': 4.995178077306196, '%Accept': 50.314465408805034, 'Overfit': True}
# {'Matchup time': 11, 'Batch': 0.3, 'Epochs': 2000, 'Loss': 74.09582836223099, '50th Quantile': 5.615151628382739, '%Accept': 47.16981132075472, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.3, 'Epochs': 3000, 'Loss': 88.76575162875578, '50th Quantile': 5.513990177449955, '%Accept': 44.0251572327044, 'Overfit': True}
# {'Matchup time': 11, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 94.9101759232815, '50th Quantile': 5.690199505199086, '%Accept': 44.65408805031446, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.4, 'Epochs': 2000, 'Loss': 88.65406976855776, '50th Quantile': 5.365956683491554, '%Accept': 44.65408805031446, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.4, 'Epochs': 3000, 'Loss': 93.55084276499238, '50th Quantile': 5.494007333643969, '%Accept': 47.16981132075472, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 105.10246291250553, '50th Quantile': 5.733179998272014, '%Accept': 46.540880503144656, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.5, 'Epochs': 2000, 'Loss': 74.5121436928803, '50th Quantile': 5.815072919938949, '%Accept': 42.138364779874216, 'Overfit': True}
# {'Matchup time': 11, 'Batch': 0.5, 'Epochs': 3000, 'Loss': 96.2474802365093, '50th Quantile': 4.793748017292112, '%Accept': 51.57232704402516, 'Overfit': True}
# {'Matchup time': 11, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 117.40002179895556, '50th Quantile': 5.559197513769703, '%Accept': 45.28301886792453, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.6, 'Epochs': 2000, 'Loss': 97.82483279630073, '50th Quantile': 6.142839586567545, '%Accept': 36.477987421383645, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.6, 'Epochs': 3000, 'Loss': 77.8959735414517, '50th Quantile': 5.494977183156202, '%Accept': 45.911949685534594, 'Overfit': True}
# {'Matchup time': 11, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 130.26444541883168, '50th Quantile': 5.5896286803973325, '%Accept': 44.0251572327044, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.7, 'Epochs': 2000, 'Loss': 80.49013008261626, '50th Quantile': 6.236941959546961, '%Accept': 38.36477987421384, 'Overfit': False}
# {'Matchup time': 11, 'Batch': 0.7, 'Epochs': 3000, 'Loss': 72.39125300953224, '50th Quantile': 5.169254720019374, '%Accept': 48.42767295597484, 'Overfit': True}
# {'Matchup time': 12, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 80.26587945906843, '50th Quantile': 6.047529928552818, '%Accept': 44.26229508196721, 'Overfit': True}
# {'Matchup time': 12, 'Batch': 0.3, 'Epochs': 2000, 'Loss': 85.82872759709593, '50th Quantile': 5.121548387807826, '%Accept': 49.18032786885246, 'Overfit': True}
# {'Matchup time': 12, 'Batch': 0.3, 'Epochs': 3000, 'Loss': 83.86042729362113, '50th Quantile': 4.757262356799265, '%Accept': 53.278688524590166, 'Overfit': True}
# {'Matchup time': 12, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 102.47706779104765, '50th Quantile': 5.117836220022166, '%Accept': 48.36065573770492, 'Overfit': False}
# {'Matchup time': 12, 'Batch': 0.4, 'Epochs': 2000, 'Loss': 85.05347255018891, '50th Quantile': 6.107078575247515, '%Accept': 42.62295081967213, 'Overfit': True}
# {'Matchup time': 12, 'Batch': 0.4, 'Epochs': 3000, 'Loss': 100.54934704890016, '50th Quantile': 6.507913576484994, '%Accept': 43.44262295081967, 'Overfit': False}
# {'Matchup time': 12, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 74.10265850629963, '50th Quantile': 5.117514480916105, '%Accept': 49.18032786885246, 'Overfit': False}
# {'Matchup time': 12, 'Batch': 0.5, 'Epochs': 2000, 'Loss': 78.57818628530033, '50th Quantile': 5.7593106105350715, '%Accept': 41.80327868852459, 'Overfit': False}
# {'Matchup time': 12, 'Batch': 0.5, 'Epochs': 3000, 'Loss': 76.13110238997663, '50th Quantile': 4.936938783580853, '%Accept': 50.81967213114754, 'Overfit': False}
# {'Matchup time': 12, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 87.91095358426453, '50th Quantile': 5.852057000826949, '%Accept': 40.98360655737705, 'Overfit': False}
# {'Matchup time': 12, 'Batch': 0.6, 'Epochs': 2000, 'Loss': 81.20479158495293, '50th Quantile': 4.917148350390844, '%Accept': 50.81967213114754, 'Overfit': True}
# {'Matchup time': 12, 'Batch': 0.6, 'Epochs': 3000, 'Loss': 68.09655386502625, '50th Quantile': 5.603954754668949, '%Accept': 45.08196721311475, 'Overfit': True}
# {'Matchup time': 12, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 105.91203720843205, '50th Quantile': 5.9582006322148855, '%Accept': 43.44262295081967, 'Overfit': False}
# {'Matchup time': 12, 'Batch': 0.7, 'Epochs': 2000, 'Loss': 66.95407879938844, '50th Quantile': 5.378519611385737, '%Accept': 44.26229508196721, 'Overfit': False}
# {'Matchup time': 12, 'Batch': 0.7, 'Epochs': 3000, 'Loss': 78.79247196385118, '50th Quantile': 5.581714820263279, '%Accept': 44.26229508196721, 'Overfit': False}
# {'Matchup time': 13, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 63.5079624778346, '50th Quantile': 5.908854707909342, '%Accept': 46.31578947368421, 'Overfit': False}
# {'Matchup time': 13, 'Batch': 0.3, 'Epochs': 2000, 'Loss': 58.40044511493883, '50th Quantile': 4.901939204985366, '%Accept': 51.578947368421055, 'Overfit': True}
# {'Matchup time': 13, 'Batch': 0.3, 'Epochs': 3000, 'Loss': 98.22065140573602, '50th Quantile': 6.301131379370595, '%Accept': 36.84210526315789, 'Overfit': True}
# {'Matchup time': 13, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 81.65924859297903, '50th Quantile': 6.7037554654208105, '%Accept': 37.89473684210527, 'Overfit': False}
# {'Matchup time': 13, 'Batch': 0.4, 'Epochs': 2000, 'Loss': 95.33754039563631, '50th Quantile': 6.282990739152238, '%Accept': 37.89473684210527, 'Overfit': True}
# {'Matchup time': 13, 'Batch': 0.4, 'Epochs': 3000, 'Loss': 86.26696110775596, '50th Quantile': 5.858261216989455, '%Accept': 43.15789473684211, 'Overfit': True}
# {'Matchup time': 13, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 95.22422605815687, '50th Quantile': 6.132333173549931, '%Accept': 38.94736842105263, 'Overfit': False}
# {'Matchup time': 13, 'Batch': 0.5, 'Epochs': 2000, 'Loss': 93.42640926963405, '50th Quantile': 5.057491687781027, '%Accept': 49.473684210526315, 'Overfit': False}
# {'Matchup time': 13, 'Batch': 0.5, 'Epochs': 3000, 'Loss': 69.94427181043123, '50th Quantile': 4.459609798247085, '%Accept': 55.78947368421052, 'Overfit': True}
# {'Matchup time': 13, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 94.52479015149568, '50th Quantile': 6.006213936522055, '%Accept': 44.21052631578947, 'Overfit': False}
# {'Matchup time': 13, 'Batch': 0.6, 'Epochs': 2000, 'Loss': 71.74732722232217, '50th Quantile': 4.859492750472674, '%Accept': 50.526315789473685, 'Overfit': True}
# {'Matchup time': 13, 'Batch': 0.6, 'Epochs': 3000, 'Loss': 87.88603491532176, '50th Quantile': 5.815318799486349, '%Accept': 45.26315789473684, 'Overfit': False}
# {'Matchup time': 13, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 90.60612620303506, '50th Quantile': 6.162213825635877, '%Accept': 38.94736842105263, 'Overfit': True}
# {'Matchup time': 13, 'Batch': 0.7, 'Epochs': 2000, 'Loss': 89.53003532008121, '50th Quantile': 5.314331079844376, '%Accept': 48.421052631578945, 'Overfit': True}
# {'Matchup time': 13, 'Batch': 0.7, 'Epochs': 3000, 'Loss': 86.13693984182257, '50th Quantile': 6.056551489877766, '%Accept': 43.15789473684211, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.3, 'Epochs': 1000, 'Loss': 84.89542811075846, '50th Quantile': 4.751813063523637, '%Accept': 53.333333333333336, 'Overfit': True}
# {'Matchup time': 14, 'Batch': 0.3, 'Epochs': 2000, 'Loss': 71.06745056152344, '50th Quantile': 5.696346976994219, '%Accept': 38.666666666666664, 'Overfit': True}
# {'Matchup time': 14, 'Batch': 0.3, 'Epochs': 3000, 'Loss': 74.43667137145997, '50th Quantile': 5.184450315985725, '%Accept': 49.333333333333336, 'Overfit': True}
# {'Matchup time': 14, 'Batch': 0.4, 'Epochs': 1000, 'Loss': 89.71303202311198, '50th Quantile': 5.006267932898215, '%Accept': 49.333333333333336, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.4, 'Epochs': 2000, 'Loss': 66.87146555582682, '50th Quantile': 5.138523737589516, '%Accept': 49.333333333333336, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.4, 'Epochs': 3000, 'Loss': 94.40472768147787, '50th Quantile': 6.617080714875852, '%Accept': 42.66666666666667, 'Overfit': True}
# {'Matchup time': 14, 'Batch': 0.5, 'Epochs': 1000, 'Loss': 86.01972412109374, '50th Quantile': 5.007508595784506, '%Accept': 49.333333333333336, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.5, 'Epochs': 2000, 'Loss': 70.57390375773112, '50th Quantile': 5.165102914322254, '%Accept': 49.333333333333336, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.5, 'Epochs': 3000, 'Loss': 87.4021531677246, '50th Quantile': 5.237260088158365, '%Accept': 48.0, 'Overfit': True}
# {'Matchup time': 14, 'Batch': 0.6, 'Epochs': 1000, 'Loss': 73.9429921468099, '50th Quantile': 5.388213663634461, '%Accept': 46.666666666666664, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.6, 'Epochs': 2000, 'Loss': 100.56453603108724, '50th Quantile': 4.956752885690626, '%Accept': 52.0, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.6, 'Epochs': 3000, 'Loss': 91.25825719197591, '50th Quantile': 5.552037418191203, '%Accept': 42.66666666666667, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.7, 'Epochs': 1000, 'Loss': 42.41916788736979, '50th Quantile': 4.002946285254172, '%Accept': 60.0, 'Overfit': False}
# {'Matchup time': 14, 'Batch': 0.7, 'Epochs': 2000, 'Loss': 84.3601572672526, '50th Quantile': 6.5456248002014945, '%Accept': 38.666666666666664, 'Overfit': True}
# {'Matchup time': 14, 'Batch': 0.7, 'Epochs': 3000, 'Loss': 88.06419728597005, '50th Quantile': 5.950531843887449, '%Accept': 46.666666666666664, 'Overfit': True}

# %%
result_df.to_csv('./results.csv')
